# %% [markdown]
# # Data Extraction

# %%
import camelot

# %%
# tables = camelot.read_pdf('C://Users//Shiva//Downloads//Python-for-PDF-master//Python-for-PDF-master//china.pdf')
tables = camelot.read_pdf('C://Users//Shiva//Downloads//new/503DM.pdf',strict=False,pages='1-end')
#tab = camelot.read_pdf('C://Users//Shiva//Downloads//new/503DM.pdf',strict=False,flavour="lattice",pages='6')

# %%
tables
# Out:
# <TableList n=97>

# %%
print(type(tables))
# Out:
# <class 'camelot.core.TableList'>

# %% [markdown]
# # Dataframe Merging

# %%
import pandas as pd
a=tables[0].df
a
# Out:
#                             0  \
# 0            Department\nACMF
# 1  Batch Record Number\n503DM
#
#                                                    1  \
# 0  Title\nPF-07063759 Re-suspension, Lysis, and F...
# 1                   Batch Number:\nProduct Code\n503
#
#                            2
# 0  Page Number\nPage 1 of 45
# 1               Version\n1.0

# %%
b=tables[1].df
su=pd.concat([a,tables[1].df],axis=0)
su
# Out:
#                                           0  \
# 0                          Department\nACMF
# 1                Batch Record Number\n503DM
# 0  BATCH PRODUCTION RECORD / ISSUE APPROVAL
# 1
# 2
# 3
# 4
# 5
#
#                                                    1  \
# 0  Title\nPF-07063759 Re-suspension, Lysis, and F...
# 1                   Batch Number:\nProduct Code\n503
# 0
# 1                               Issued By/Print Name
# 2
# 3                             Reviewed By/Print Name
# 4
# 5
#
#                            2         3    4                   5    6
# 0  Page Number\nPage 1 of 45       NaN  NaN                 NaN  NaN
# 1               Version\n1.0       NaN  NaN                 NaN  NaN
# 0
# 1                             Job Role       Signature and Date
# 2
# 3                             Job Role       Signature and Date
# 4
# 5

# %%
#using list comprehension 
import pandas as pd
f=pd.DataFrame()
f=[pd.concat([f,i.df],axis=0) for i in tables]

# %%
f
# Out:
# [                            0  \
#  0            Department\nACMF
#  1  Batch Record Number\n503DM
#
#                                                     1  \
#  0  Title\nPF-07063759 Re-suspension, Lysis, and F...
#  1                   Batch Number:\nProduct Code\n503
#
#                             2
#  0  Page Number\nPage 1 of 45
#  1               Version\n1.0  ,
#                                            0                       1 2  \
#  0  BATCH PRODUCTION RECORD / ISSUE APPROVAL
#  1                                              Issued By/Print Name
#  2
#  3                                            Reviewed By/Print Name
#  4
#  5
#
#            3 4                   5 6
#  0
#  1  Job Role    Signature and Date
#  2
#  3  Job Role    Signature and Date
#  4
#  5                                    ,
#                              0  \
#  0            Department\nACMF
#  1  Batch Record Number\n503DM
#
#                                                     1  \
# ...

# %%
final=pd.DataFrame()
#fin=[pd.concat([fin,i.df],axis=0) for i in tables]
for i in tables:
    new=i.df
    final=pd.concat([final,new], axis=0)
final
# Out:
#                                                     0  \
# 0                                    Department\nACMF
# 1                          Batch Record Number\n503DM
# 0            BATCH PRODUCTION RECORD / ISSUE APPROVAL
# 1
# 2
# ..                                                ...
# 1                        Conforming\n  Non-conforming
# 2   If Non-conforming add comment otherwise N/A   ...
# 3                          QA\nDisposition \nApprover
# 0                                    Department\nACMF
# 1                          Batch Record Number\n503DM
#
#                                                     1  \
# 0   Title\nPF-07063759 Re-suspension, Lysis, and F...
# 1                    Batch Number:\nProduct Code\n503
# 0
# 1                                Issued By/Print Name
# 2
# ..                                                ...
# 1
# 2
# 3                                         Print Name:
# 0   Title\nPF-07063759 Re-suspension, Lysis, and F...
# ...

# %%
final.shape
# Out:
# (691, 10)

# %%
final.isnull().sum()
# Out:
# 0      0
# 1      4
# 2    193
# 3    571
# 4    607
# 5    640
# 6    654
# 7    677
# 8    677
# 9    677
# dtype: int64

# %% [markdown]
# # Data Transformation

# %%
import sqlalchemy
import psycopg2 as psg

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:abc@localhost/pfizer")
con = engine.connect()

# %%
print(engine.table_names())
# Out:
# ['industry_production', 'industry_production_test']

# %%
table_name = 'industry'
final.to_sql(table_name, con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-679ed32934f1> in <module>
#       1 table_name = 'industry'
# ----> 2 final.to_sql(table_name, con)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
# ...
